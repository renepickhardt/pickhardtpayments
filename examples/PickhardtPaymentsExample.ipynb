# %% [markdown]
# # Pickhardt Payments Example
#
# Example code demonstrating how to use the `pickhardtpayments` package in python. You need to install the library via `pip install pickhardtpayments` or you can download the full source code at https://ln.rene-pickhardt.de or a copy from github at: https://www.github.com/renepickhardt/pickhardtpayments
#
# Of course you can use the classes in the library to create your own async payment loop or you could exchange the Oracle to talk to the actual Lightning network by wrapping against your favourite node implementation and exposing the the `send_onion` call.
#
# This example assumes a randomly generated Oracle to conduct payments in a simulated way. For this you will need an actual channelgraph which you can get for example with `lightning-cli listchannels > listchannels20220412.json`
#
# ## Acknowledgements & Funding
# This work is funded via various sources including NTNU & BitMEX as well as many generous donors via https://donate.ln.rene-pickhardt.de or https://www.patreon.com/renepickhardt Feel free to go to my website at https://ln.rene-pickhardt.de to learn how I have been contributing to the open source community and why it is important to have independent open source contributors. In case you also wish to support me I will be very grateful

# %%
from pickhardtpayments.ChannelGraph import ChannelGraph
from pickhardtpayments.UncertaintyNetwork import UncertaintyNetwork
from pickhardtpayments.OracleLightningNetwork import OracleLightningNetwork
from pickhardtpayments.SyncSimulatedPaymentSession import SyncSimulatedPaymentSession

# %%
#Rene Pickhardt's public node key
RENE = "03efccf2c383d7bf340da9a3f02e2c23104a0e4fe8ac1a880c8e2dc92fbdacd9df"
#Carsten Otto's public node key
C_OTTO = "027ce055380348d7812d2ae7745701c9f93e70c1adeb2657f053f91df4f2843c71"

#we first need to import the chanenl graph from core lightning jsondump
#you can get your own data set via:
# $: lightning-cli listchannels > listchannels20220412.json
# alternatively you can go to https://ln.rene-pickhardt.de to find a data dump
channel_graph = ChannelGraph("listchannels20220412.json")

#we now create an Oracle. This is a Simulated Network that assumes uniform distribution 
#of the liquidity for the channels on the `channel_graph`. Of course one could create one's own 
#oracle (for example a wrapper to an existing lightning network node / implementation)
oracle_lightning_network = OracleLightningNetwork(channel_graph)

# %%
# Since we randomly generated our Oracle but also since we control it we can compute
# The maximum possible amount that can be payed between two nodes
maximum_payable_amount =oracle_lightning_network.theoretical_maximum_payable_amount(RENE,C_OTTO,1000)
print(maximum_payable_amount, "sats would be possible on this oracle to deliver if including 1 sat basefee channels")
# Out:
# 107179625 sats would be possible on this oracle to deliver if including 1 sat basefee channels

# %%
#Of course we want to restrict ourselves to the zeroBaseFee part of the network.
#Therefore we compute the theoretical maximum payable amount for that subgraph
maximum_payable_amount =oracle_lightning_network.theoretical_maximum_payable_amount(RENE,C_OTTO,0)
print(maximum_payable_amount, "sats possible on this oracle on the zeroBaseFeeGraph")
# Out:
# 55795527 sats possible on this oracle on the zeroBaseFeeGraph

# %%
# We choose an amount that is half the theoretical maximum to demonstrate the
# minimum cost flow solver with Bayesian updates on the Uncertainty Network finds the
# liquidity rather quickly
tested_amount = int(maximum_payable_amount/2)

# From the channel graph we can derive our initial Uncertainty Network which is the main data structure
# that we maintain in order to deliver sats from one node to another
uncertainty_network = UncertaintyNetwork(channel_graph)

#we create a payment session which in this case operates by sending out the onions
#sequentially 
payment_session = SyncSimulatedPaymentSession(oracle_lightning_network, 
                                 uncertainty_network,
                                 prune_network=False)

#we need to make sure we forget all learnt information on the Uncertainty Nework
payment_session.forget_information()

#we run the simulation of pickhardt payments and track all the results
payment_session.pickhardt_pay(RENE,C_OTTO, tested_amount,mu=0,base=0)
# Out:
# Round number:  1
# Try to deliver 27897763 satoshi:
#
# Statistics about 10 candidate onions:
#
# successful attempts:
# --------------------
#  p =  80.89% amt:   1000000 sats  hops: 3 ppm:  1897
#  p =  93.93% amt:    356886 sats  hops: 3 ppm:  1973
#  p =  54.14% amt:   3000000 sats  hops: 5 ppm:  2580
#  p =  46.45% amt:    969011 sats  hops: 5 ppm:  2057
#
# failed attempts:
# ----------------
#  p =  25.52% amt:  10066329 sats  hops: 3 ppm:  2036
#  p =  77.91% amt:    796094 sats  hops: 4 ppm:  2059
#  p =  50.98% amt:   3355443 sats  hops: 4 ppm:  2496
#  p =  42.69% amt:   3051434 sats  hops: 5 ppm:  2551
#  p =  29.38% amt:   5000000 sats  hops: 6 ppm:  5318
#  p =  35.76% amt:    302566 sats  hops: 7 ppm:  3251
#
# Attempt Summary:
# =================
#
# Tried to deliver   27897763 sats
# expected to deliver   10997273 sats 	(39.42%)
# actually deliverd    5325897 sats 	(19.09%)
# deviation: 0.48
# planned_fee: 78220.517 sat
# paid fees: 12335.715 sat
# Runtime of flow computation: 0.49 sec
#
# ================================================================
#
# Round number:  2
# Try to deliver 22571866 satoshi:
#
# Statistics about 12 candidate onions:
#
# successful attempts:
# --------------------
#  p =  75.20% amt:    600000 sats  hops: 2 ppm:  2572
#  p =  67.98% amt:    882941 sats  hops: 3 ppm:  1566
#  p =  77.59% amt:   1948622 sats  hops: 3 ppm:  1973
#  p =  68.37% amt:   1000000 sats  hops: 4 ppm:  2187
#  p =  86.05% amt:    200173 sats  hops: 4 ppm:  2496
#  p =  94.17% amt:    121045 sats  hops: 4 ppm:  2563
#  p =  53.18% amt:   1847070 sats  hops: 5 ppm:  2059
#  p =  57.55% amt:   1000000 sats  hops: 6 ppm:  5318
#  p =  57.60% amt:    518955 sats  hops: 6 ppm:  3263
#
# failed attempts:
# ----------------
#  p =  14.08% amt:   8053060 sats  hops: 3 ppm:  2036
#  p =  62.61% amt:   1600000 sats  hops: 5 ppm:  2897
#  p =  21.85% amt:   4800000 sats  hops: 5 ppm:  2580
#
# Attempt Summary:
# =================
#
# Tried to deliver   22571866 sats
# expected to deliver    8574252 sats 	(37.99%)
# actually deliverd    8118806 sats 	(35.97%)
# deviation: 0.95
# planned_fee: 54010.646 sat
# paid fees: 20587.363 sat
# Runtime of flow computation: 0.52 sec
#
# ================================================================
#
# Round number:  3
# Try to deliver 14453060 satoshi:
#
# Statistics about 11 candidate onions:
#
# successful attempts:
# --------------------
#  p =  69.65% amt:    800000 sats  hops: 4 ppm:  2187
#  p =  69.70% amt:    706353 sats  hops: 4 ppm: 21456
#  p =  78.16% amt:    749028 sats  hops: 5 ppm:  2974
#  p =  65.72% amt:    960000 sats  hops: 5 ppm:  2580
#  p =  48.61% amt:   1200000 sats  hops: 5 ppm:  8863
#  p =  68.83% amt:    630586 sats  hops: 5 ppm: 21759
#  p =  79.44% amt:    216359 sats  hops: 6 ppm:  3791
#  p =  65.14% amt:    800000 sats  hops: 6 ppm:  5317
#
# failed attempts:
# ----------------
#  p =  77.85% amt:   1558898 sats  hops: 3 ppm:  1973
#  p =  32.64% amt:   4831836 sats  hops: 3 ppm:  2036
#  p =  57.16% amt:   2000000 sats  hops: 5 ppm:  3107
#
# Attempt Summary:
# =================
#
# Tried to deliver   14453060 sats
# expected to deliver    7910274 sats 	(54.73%)
# actually deliverd    6062326 sats 	(41.94%)
# deviation: 0.77
# planned_fee: 70176.661 sat
# paid fees: 51042.949 sat
# Runtime of flow computation: 0.48 sec
#
# ================================================================
#
# Round number:  4
# Try to deliver 8390734 satoshi:
#
# Statistics about 10 candidate onions:
#
# successful attempts:
# --------------------
#  p =  91.17% amt:    165508 sats  hops: 4 ppm:  1869
#  p =  76.24% amt:    437251 sats  hops: 4 ppm:  2496
#  p =  68.86% amt:   2000000 sats  hops: 4 ppm:  2502
#  p =  62.44% amt:    558898 sats  hops: 5 ppm:  2974
#  p =  72.14% amt:    640000 sats  hops: 6 ppm:  5318
#  p =  80.71% amt:    311728 sats  hops: 6 ppm:  3181
#  p =  90.63% amt:     77383 sats  hops: 6 ppm:  2590
#
# failed attempts:
# ----------------
#  p =  55.40% amt:   1932734 sats  hops: 3 ppm:  2036
#  p =  72.65% amt:    640000 sats  hops: 4 ppm:  2187
#  p =  61.44% amt:   1000000 sats  hops: 4 ppm:  1687
#
# Attempt Summary:
# =================
#
# Tried to deliver    7763502 sats
# expected to deliver    5143778 sats 	(66.26%)
# actually deliverd    4190768 sats 	(53.98%)
# deviation: 0.81
# planned_fee: 19687.622 sat
# paid fees: 12663.964 sat
# Runtime of flow computation: 0.52 sec
#
# ================================================================
#
# Round number:  5
# Try to deliver 3572734 satoshi:
#
# Statistics about 5 candidate onions:
#
# successful attempts:
# --------------------
#  p =  54.49% amt:   1000000 sats  hops: 4 ppm:  2187
#  p =  71.75% amt:     31771 sats  hops: 5 ppm:  2579
#  p =  72.80% amt:    512000 sats  hops: 6 ppm:  5318
#
# failed attempts:
# ----------------
#  p =  72.52% amt:    800000 sats  hops: 4 ppm:  2537
#  p =  60.75% amt:   1228963 sats  hops: 6 ppm:  3366
#
# Attempt Summary:
# =================
#
# Tried to deliver    3572734 sats
# expected to deliver    2267238 sats 	(63.46%)
# actually deliverd    1543771 sats 	(43.21%)
# deviation: 0.68
# planned_fee: 11159.299 sat
# paid fees: 4991.783 sat
# Runtime of flow computation: 0.45 sec
#
# ================================================================
#
# Round number:  6
# Try to deliver 2028963 satoshi:
#
# Statistics about 2 candidate onions:
#
# successful attempts:
# --------------------
#  p =  64.91% amt:    800000 sats  hops: 5 ppm:  8863
#  p =  96.34% amt:   1228963 sats  hops: 7 ppm:  3366
#
# Attempt Summary:
# =================
#
# Tried to deliver    2028963 sats
# expected to deliver    1703297 sats 	(83.95%)
# actually deliverd    2028963 sats 	(100.00%)
# deviation: 1.19
# planned_fee: 11228.316 sat
# paid fees: 11228.316 sat
# Runtime of flow computation: 0.37 sec
#
# ================================================================
#
# SUMMARY:
# ========
# Rounds of mcf-computations:  6
# Number of onions sent:  50
# Number of failed onions:  17
# Failure rate: 34.00%
# total runtime (including inefficient memory managment): 7.994 sec
# Learnt entropy: 55.26 bits
# Fees for successfull delivery: 112850.090 sat --> 4045 ppm
# used mu: 0

# %% [markdown]
# ## Optimizing for Fees
#
# controlling mu we can decide how much we wish to focus on lower fees. However ,we will see that it will be much harder to deliver the same amount in the sense that we need to send out more onions and also have more failed attampts. Consequently we expect to need more time.

# %%
#we need to make sure we forget all learnt information on the Uncertainty Nework
payment_session.forget_information()

#we run the simulation of pickhardt payments and track all the results
payment_session.pickhardt_pay(RENE,C_OTTO, tested_amount,mu=100,base=0)
# Out:
# Round number:  1
# Try to deliver 27897763 satoshi:
#
# Statistics about 14 candidate onions:
#
# successful attempts:
# --------------------
#  p =  36.00% amt:   2000000 sats  hops: 2 ppm:  1360
#  p =  22.22% amt:    998574 sats  hops: 4 ppm:  1367
#  p =  61.34% amt:    600000 sats  hops: 5 ppm:  1375
#
# failed attempts:
# ----------------
#  p =  70.75% amt:   1000000 sats  hops: 3 ppm:  1352
#  p =  19.37% amt:   4906248 sats  hops: 3 ppm:  1365
#  p =  35.39% amt:    740000 sats  hops: 3 ppm:  1381
#  p =  43.15% amt:   2000000 sats  hops: 4 ppm:  1376
#  p =  20.72% amt:   1000000 sats  hops: 4 ppm:  1379
#  p =  14.17% amt:   4200000 sats  hops: 5 ppm:  1362
#  p =   3.63% amt:   3452941 sats  hops: 5 ppm:  1352
#  p =   5.84% amt:   1000000 sats  hops: 6 ppm:  1354
#  p =   0.19% amt:   4000000 sats  hops: 6 ppm:  1362
#  p =   0.00% amt:   1117059 sats  hops: 6 ppm:  1361
#  p =  40.77% amt:    882941 sats  hops: 6 ppm:  1373
#
# Attempt Summary:
# =================
#
# Tried to deliver   27897763 sats
# expected to deliver    5446668 sats 	(19.52%)
# actually deliverd    3598574 sats 	(12.90%)
# deviation: 0.66
# planned_fee: 38046.738 sat
# paid fees: 4911.048 sat
# Runtime of flow computation: 0.54 sec
#
# ================================================================
#
# Round number:  2
# Try to deliver 24299189 satoshi:
#
# Statistics about 35 candidate onions:
#
# successful attempts:
# --------------------
#  p =  74.13% amt:    220000 sats  hops: 2 ppm:  1339
#  p =  78.46% amt:    192000 sats  hops: 2 ppm:  1342
#  p =  76.00% amt:    200000 sats  hops: 2 ppm:  1382
#  p =  72.00% amt:    200000 sats  hops: 2 ppm:  1357
#  p =  29.60% amt:   1862646 sats  hops: 3 ppm:  1487
#  p =  58.88% amt:    400000 sats  hops: 3 ppm:  1381
#  p =  47.15% amt:    900000 sats  hops: 3 ppm:  1416
#  p =  19.55% amt:   2054146 sats  hops: 4 ppm:  1413
#  p =  47.32% amt:    400000 sats  hops: 4 ppm:  1411
#  p =  20.37% amt:   1000000 sats  hops: 5 ppm:  1415
#  p =  25.03% amt:    145854 sats  hops: 5 ppm:  1422
#  p =  73.91% amt:    177822 sats  hops: 5 ppm:  1369
#  p =  34.00% amt:    200000 sats  hops: 5 ppm:  1370
#  p =  67.48% amt:    200000 sats  hops: 5 ppm:  1362
#  p =  72.35% amt:      4557 sats  hops: 6 ppm:  1368
#  p =  32.44% amt:    100000 sats  hops: 6 ppm:  1426
#  p =  53.60% amt:      4557 sats  hops: 6 ppm:  1386
#  p =  21.06% amt:    475443 sats  hops: 8 ppm:  1371
#
# failed attempts:
# ----------------
#  p =  64.00% amt:    600000 sats  hops: 2 ppm:  1360
#  p =  73.92% amt:    194200 sats  hops: 3 ppm:  1362
#  p =  13.61% amt:   3180754 sats  hops: 3 ppm:  1365
#  p =  33.60% amt:   1000000 sats  hops: 3 ppm:  1360
#  p =  55.13% amt:    102454 sats  hops: 4 ppm:  1391
#  p =  39.39% amt:   1897546 sats  hops: 4 ppm:  1417
#  p =  64.94% amt:    200000 sats  hops: 5 ppm:  1353
#  p =  63.63% amt:    180000 sats  hops: 5 ppm:  1353
#  p =  37.41% amt:    960000 sats  hops: 5 ppm:  1375
#  p =  70.33% amt:    369562 sats  hops: 5 ppm:  1349
#  p =  67.05% amt:    180000 sats  hops: 5 ppm:  1347
#  p =  64.71% amt:    115443 sats  hops: 6 ppm:  1367
#  p =   7.19% amt:   2000000 sats  hops: 6 ppm:  1405
#  p =  33.36% amt:    400000 sats  hops: 6 ppm:  1348
#  p =  37.69% amt:    500000 sats  hops: 6 ppm:  1353
#  p =  28.35% amt:   1880000 sats  hops: 7 ppm:  1387
#  p =  15.00% amt:   1000000 sats  hops: 8 ppm:  1392
#
# Attempt Summary:
# =================
#
# Tried to deliver   23496984 sats
# expected to deliver    7432674 sats 	(31.63%)
# actually deliverd    8737025 sats 	(37.18%)
# deviation: 1.18
# planned_fee: 32765.068 sat
# paid fees: 12387.442 sat
# Runtime of flow computation: 0.53 sec
#
# ================================================================
#
# Round number:  3
# Try to deliver 14759959 satoshi:
#
# Statistics about 33 candidate onions:
#
# successful attempts:
# --------------------
#  p =  74.94% amt:    176000 sats  hops: 2 ppm:  1339
#  p =  76.63% amt:    160000 sats  hops: 2 ppm:  1382
#  p =  60.48% amt:    380000 sats  hops: 3 ppm:  1506
#  p =  55.65% amt:    108920 sats  hops: 3 ppm:  1387
#  p =  55.97% amt:    254940 sats  hops: 3 ppm:  1487
#  p =  43.00% amt:   1000000 sats  hops: 3 ppm:  1507
#  p =  76.71% amt:    133333 sats  hops: 3 ppm:  1378
#  p =  28.94% amt:    886160 sats  hops: 4 ppm:  1413
#  p =  53.36% amt:    320000 sats  hops: 4 ppm:  1411
#  p =  73.13% amt:    192000 sats  hops: 5 ppm:  1375
#  p =  51.18% amt:     73840 sats  hops: 5 ppm:  1414
#  p =  73.07% amt:    142257 sats  hops: 5 ppm:  1361
#  p =  79.80% amt:    369562 sats  hops: 5 ppm:  1341
#  p =  48.69% amt:    329088 sats  hops: 6 ppm:  1566
#  p =  72.89% amt:    214341 sats  hops: 6 ppm:  1344
#  p =  44.38% amt:     80000 sats  hops: 7 ppm:  1426
#  p =  57.00% amt:    200000 sats  hops: 8 ppm:  1392
#  p =  43.40% amt:    400000 sats  hops: 8 ppm:  1399
#  p =  41.87% amt:    180000 sats  hops: 8 ppm:  1358
#  p =  37.83% amt:    200000 sats  hops: 9 ppm:  1379
#  p =  26.05% amt:    160000 sats  hops: 10 ppm:  1369
#
# failed attempts:
# ----------------
#  p =  78.75% amt:    153600 sats  hops: 2 ppm:  1341
#  p =  72.89% amt:    160000 sats  hops: 2 ppm:  1357
#  p =  13.23% amt:   2635564 sats  hops: 3 ppm:  1365
#  p =  59.55% amt:    320000 sats  hops: 3 ppm:  1381
#  p =  44.13% amt:    720000 sats  hops: 3 ppm:  1416
#  p =  13.41% amt:   2300000 sats  hops: 5 ppm:  1370
#  p =  49.82% amt:    160000 sats  hops: 5 ppm:  1362
#  p =  36.64% amt:    310000 sats  hops: 6 ppm:  1400
#  p =  64.39% amt:    570912 sats  hops: 7 ppm:  1566
#  p =  56.13% amt:    400000 sats  hops: 7 ppm:  1367
#  p =  48.08% amt:    283783 sats  hops: 7 ppm:  1386
#  p =  21.96% amt:    785659 sats  hops: 8 ppm:  1353
#
# Attempt Summary:
# =================
#
# Tried to deliver   14759959 sats
# expected to deliver    5553902 sats 	(37.63%)
# actually deliverd    5960441 sats 	(40.38%)
# deviation: 1.07
# planned_fee: 20695.106 sat
# paid fees: 8508.514 sat
# Runtime of flow computation: 0.51 sec
#
# ================================================================
#
# Round number:  4
# Try to deliver 8799518 satoshi:
#
# Statistics about 21 candidate onions:
#
# successful attempts:
# --------------------
#  p =  77.19% amt:    128000 sats  hops: 2 ppm:  1382
#  p =  52.10% amt:    700000 sats  hops: 3 ppm:  1361
#  p =  51.68% amt:    215492 sats  hops: 3 ppm:  1487
#  p =  91.79% amt:     47019 sats  hops: 4 ppm:  1410
#  p =  70.06% amt:    153600 sats  hops: 5 ppm:  1374
#  p =  69.49% amt:    160000 sats  hops: 5 ppm:  1447
#  p =  68.30% amt:    160990 sats  hops: 6 ppm:  1497
#  p =  60.11% amt:    336000 sats  hops: 7 ppm:  1424
#  p =  56.72% amt:    337587 sats  hops: 7 ppm:  1569
#  p =  44.28% amt:    161559 sats  hops: 7 ppm:  1371
#  p =  76.48% amt:    285659 sats  hops: 8 ppm:  1353
#  p =  34.66% amt:    310027 sats  hops: 8 ppm:  1371
#
# failed attempts:
# ----------------
#  p =  31.26% amt:   1817782 sats  hops: 3 ppm:  1365
#  p =  66.17% amt:    800000 sats  hops: 5 ppm:  1367
#  p =  76.88% amt:    140800 sats  hops: 5 ppm:  1348
#  p =  83.87% amt:    800000 sats  hops: 5 ppm:  1370
#  p =  43.96% amt:    640000 sats  hops: 7 ppm:  1435
#  p =  57.11% amt:    233325 sats  hops: 7 ppm:  1551
#  p =  45.84% amt:    160000 sats  hops: 7 ppm:  1392
#  p =  35.97% amt:    400000 sats  hops: 7 ppm:  1352
#  p =  33.51% amt:    811678 sats  hops: 8 ppm:  1469
#
# Attempt Summary:
# =================
#
# Tried to deliver    8799518 sats
# expected to deliver    4518303 sats 	(51.35%)
# actually deliverd    2995933 sats 	(34.05%)
# deviation: 0.66
# planned_fee: 12342.562 sat
# paid fees: 4242.734 sat
# Runtime of flow computation: 0.53 sec
#
# ================================================================
#
# Round number:  5
# Try to deliver 5803585 satoshi:
#
# Statistics about 11 candidate onions:
#
# successful attempts:
# --------------------
#  p =  84.64% amt:    800000 sats  hops: 4 ppm:  1384
#  p =  80.19% amt:    320000 sats  hops: 5 ppm:  1456
#  p =  79.23% amt:    157047 sats  hops: 5 ppm:  1590
#  p =  56.44% amt:    800000 sats  hops: 5 ppm:  1394
#  p =  63.74% amt:    400000 sats  hops: 8 ppm:  1484
#  p =  84.94% amt:    411678 sats  hops: 10 ppm:  1459
#
# failed attempts:
# ----------------
#  p =  53.87% amt:   1204445 sats  hops: 3 ppm:  1365
#  p =  71.27% amt:    301186 sats  hops: 3 ppm:  1506
#  p =  58.15% amt:    246596 sats  hops: 4 ppm:  1410
#  p =  55.29% amt:    268800 sats  hops: 4 ppm:  1413
#  p =  37.83% amt:    893833 sats  hops: 5 ppm:  1558
#
# Attempt Summary:
# =================
#
# Tried to deliver    5803585 sats
# expected to deliver    3608001 sats 	(62.17%)
# actually deliverd    2888725 sats 	(49.77%)
# deviation: 0.80
# planned_fee: 8353.489 sat
# paid fees: 4132.825 sat
# Runtime of flow computation: 0.47 sec
#
# ================================================================
#
# Round number:  6
# Try to deliver 2914860 satoshi:
# Statistics about 9 candidate onions:
#
# successful attempts:
# --------------------
#  p =  76.33% amt:   1000000 sats  hops: 3 ppm:  1366
#  p =  58.03% amt:    178216 sats  hops: 3 ppm:  1387
#  p =  55.32% amt:    300000 sats  hops: 5 ppm:  1523
#  p =  71.23% amt:     76278 sats  hops: 5 ppm:  1558
#  p =  75.21% amt:    122880 sats  hops: 5 ppm:  1374
#
# failed attempts:
# ----------------
#  p =  64.18% amt:    324000 sats  hops: 3 ppm:  1506
#  p =  78.50% amt:    100902 sats  hops: 3 ppm:  1378
#  p =  61.99% amt:    113806 sats  hops: 4 ppm:  1360
#  p =  44.63% amt:    698778 sats  hops: 5 ppm:  1594
#
# Attempt Summary:
# =================
#
# Tried to deliver    2914860 sats
# expected to deliver    1848980 sats 	(63.43%)
# actually deliverd    1677374 sats 	(57.55%)
# deviation: 0.91
# planned_fee: 4254.657 sat
# paid fees: 2358.134 sat
# Runtime of flow computation: 0.48 sec
#
# ================================================================
#
# Round number:  7
# Try to deliver 1237486 satoshi:
#
# Statistics about 4 candidate onions:
#
# successful attempts:
# --------------------
#  p =  79.12% amt:    324000 sats  hops: 4 ppm:  1506
#  p =  81.05% amt:    698778 sats  hops: 4 ppm:  1647
#  p =  93.64% amt:     40846 sats  hops: 7 ppm:  1476
#
# failed attempts:
# ----------------
#  p =  62.53% amt:    173862 sats  hops: 5 ppm:  1459
#
# Attempt Summary:
# =================
#
# Tried to deliver    1237486 sats
# expected to deliver     969676 sats 	(78.36%)
# actually deliverd    1063624 sats 	(85.95%)
# deviation: 1.10
# planned_fee: 1953.692 sat
# paid fees: 1699.857 sat
# Runtime of flow computation: 0.47 sec
#
# ================================================================
#
# Round number:  8
# Try to deliver 173862 satoshi:
#
# Statistics about 3 candidate onions:
#
# successful attempts:
# --------------------
#  p =  81.18% amt:     85931 sats  hops: 2 ppm:  1381
#  p =  98.71% amt:     10000 sats  hops: 5 ppm:  1523
#  p =  88.05% amt:     77931 sats  hops: 6 ppm:  1477
#
# Attempt Summary:
# =================
#
# Tried to deliver     173862 sats
# expected to deliver     148245 sats 	(85.27%)
# actually deliverd     173862 sats 	(100.00%)
# deviation: 1.17
# planned_fee:  249.164 sat
# paid fees:  249.164 sat
# Runtime of flow computation: 0.41 sec
#
# ================================================================
#
# SUMMARY:
# ========
# Rounds of mcf-computations:  8
# Number of onions sent:  130
# Number of failed onions:  59
# Failure rate: 45.38%
# total runtime (including inefficient memory managment): 10.700 sec
# Learnt entropy: 171.13 bits
# Fees for successfull delivery: 38489.718 sat --> 1379 ppm
# used mu: 100
